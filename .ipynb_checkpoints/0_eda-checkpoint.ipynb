# %% [markdown]
# # Indonesia Covid-19 Cases by Provinces

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import folium as fo
from folium.plugins import FloatImage

# %% [markdown]
# <hr>
#
# ### 1. Sraping data from [Wikipedia](https://en.wikipedia.org/wiki/2020_coronavirus_pandemic_in_Indonesia)

# %%
# 1a. basic pandas read html table
# data = pd.read_html('https://en.wikipedia.org/wiki/2020_coronavirus_pandemic_in_Indonesia')

# %%
# data[3]

# %%
# 1b. pandas read html from https request
url = 'https://en.wikipedia.org/wiki/2020_coronavirus_pandemic_in_Indonesia'
x = requests.get(url)
datacorona = pd.read_html(x.text)

# %%
datacorona[3]
# Out:
#                                              Province  \
#                                              Province
# 0                                                Aceh
# 1                                                Bali
# 2                             Bangka Belitung Islands
# 3                                              Banten
# 4                                            Bengkulu
# 5                                        Central Java
# 6                                  Central Kalimantan
# 7                                    Central Sulawesi
# 8                                           East Java
# 9                                     East Kalimantan
# 10                                 East Nusa Tenggara
# 11                                          Gorontalo
# 12                                         Jakarta[b]
# 13                                              Jambi
# 14                                            Lampung
# 15                                             Maluku
# 16                                   North Kalimantan
# 17                                       North Maluku
# 18                                     North Sulawesi
# 19                                   North Sumatra[c]
# 20                                              Papua
# 21                                               Riau
# 22                                       Riau Islands
# 23                                   South Kalimantan
# 24                                     South Sulawesi
# 25                                      South Sumatra
# 26                                 Southeast Sulawesi
# 27                       Special Region of Yogyakarta
# 28                                          West Java
# 29                                    West Kalimantan
# 30                                 West Nusa Tenggara
# 31                                         West Papua
# 32                                      West Sulawesi
# 33                                       West Sumatra
# 34                                Under investigation
# 35                                              Total
# 36  Data as of 20 April 2020[27] ^ Counting by cen...
#
#                                         First case(s)  \
#                                                  Date
# 0                                            26 March
# 1                                            10 March
# 2                                            30 March
# 3                                             8 March
# 4                                            31 March
# 5                                             9 March
# 6                                            20 March
# 7                                            26 March
# 8                                            17 March
# 9                                            18 March
# 10                                            9 April
# 11                                            9 April
# 12                                            2 March
# 13                                           23 March
# 14                                           18 March
# 15                                           22 March
# 16                                           28 March
# 17                                           23 March
# 18                                           14 March
# 19                                           18 March
# 20                                           22 March
# 21                                           18 March
# 22                                           17 March
# 23                                           22 March
# 24                                           19 March
# 25                                           24 March
# 26                                           19 March
# 27                                           13 March
# 28                                            2 March
# 29                                           10 March
# 30                                           24 March
# 31                                           27 March
# 32                                           29 March
# 33                                           26 March
# 34                                Under investigation
# 35                                              Total
# 36  Data as of 20 April 2020[27] ^ Counting by cen...
#
#                                                        \
#                                              Location
# 0                                          Banda Aceh
# 1                                            Denpasar
# 2                                    Belitung Regency
# 3                                              Serang
# 4                                            Bengkulu
# 5                                                Solo
# 6                                        Palangkaraya
# 7                                                Palu
# 8                                            Surabaya
# 9                                           Samarinda
# 10                                       Alor Regency
# 11                               Bone Bolango Regency
# 12                                             Kemang
# 13                                              Jambi
# 14                                     Bandar Lampung
# 15                                              Ambon
# 16                          Tanjung Selor and Tarakan
# 17                                            Ternate
# 18                                             Manado
# 19                                              Medan
# 20                                            Merauke
# 21                                          Pekanbaru
# 22                                     Tanjung Pinang
# 23                                        Banjarmasin
# 24                                           Makassar
# 25                                          Palembang
# 26                                            Kendari
# 27                                         Yogyakarta
# 28                                              Depok
# 29                                          Pontianak
# 30                                            Mataram
# 31                                             Sorong
# 32                                     Mamuju Regency
# 33                                        Bukittinggi
# 34                                Under investigation
# 35                                              Total
# 36  Data as of 20 April 2020[27] ^ Counting by cen...
#
#                                             Confirmed  \
#                                                 6,760
# 0                                                   7
# 1                                                 140
# 2                                                   7
# 3                                                 341
# 4                                                   4
# 5                                                 351
# 6                                                  60
# 7                                                  27
# 8                                                 588
# 9                                                  59
# 10                                                  1
# 11                                                  4
# 12                                               3097
# 13                                                  8
# 14                                                 26
# 15                                                 17
# 16                                                 74
# 17                                                  4
# 18                                                 20
# 19                                                 83
# 20                                                107
# 21                                                 34
# 22                                                 79
# 23                                                 96
# 24                                                370
# 25                                                 89
# 26                                                 37
# 27                                                 69
# 28                                                747
# 29                                                 21
# 30                                                 72
# 31                                                  7
# 32                                                  7
# 33                                                 74
# 34                                                 27
# 35                                               6760
# 36  Data as of 20 April 2020[27] ^ Counting by cen...
#
#                                             Recovered  \
#                                                   747
# 0                                                   4
# 1                                                  42
# 2                                                   1
# 3                                                  17
# 4                                                   0
# 5                                                  51
# 6                                                   9
# 7                                                   2
# 8                                                  99
# 9                                                  11
# 10                                                  0
# 11                                                  0
# 12                                                230
# 13                                                  1
# 14                                                 10
# 15                                                 10
# 16                                                  2
# 17                                                  2
# 18                                                  5
# 19                                                 13
# 20                                                 28
# 21                                                  9
# 22                                                  6
# 23                                                  9
# 24                                                 63
# 25                                                  5
# 26                                                  4
# 27                                                 28
# 28                                                 56
# 29                                                  6
# 30                                                 11
# 31                                                  0
# 32                                                  1
# 33                                                 13
# 34                                                  0
# 35                                                747
# 36  Data as of 20 April 2020[27] ^ Counting by cen...
#
#                                                Deaths  \
#                                                   590
# 0                                                   1
# 1                                                   3
# 2                                                   1
# 3                                                  35
# 4                                                   1
# 5                                                  44
# 6                                                   3
# 7                                                   3
# 8                                                  56
# 9                                                   1
# 10                                                  0
# 11                                                  0
# 12                                                287
# 13                                                  0
# 14                                                  5
# 15                                                  0
# 16                                                  1
# 17                                                  0
# 18                                                  2
# 19                                                  9
# 20                                                  6
# 21                                                  4
# 22                                                  7
# 23                                                  6
# 24                                                 25
# 25                                                  3
# 26                                                  2
# 27                                                  7
# 28                                                 62
# 29                                                  3
# 30                                                  4
# 31                                                  1
# 32                                                  1
# 33                                                  7
# 34                                                  0
# 35                                                590
# 36  Data as of 20 April 2020[27] ^ Counting by cen...
#
#                                                Active  \
#                                                 5,423
# 0                                                   2
# 1                                                  95
# 2                                                   5
# 3                                                 289
# 4                                                   3
# 5                                                 256
# 6                                                  48
# 7                                                  22
# 8                                                 433
# 9                                                  47
# 10                                                  1
# 11                                                  4
# 12                                               2580
# 13                                                  7
# 14                                                 11
# 15                                                  7
# 16                                                 71
# 17                                                  2
# 18                                                 13
# 19                                                 61
# 20                                                 73
# 21                                                 21
# 22                                                 66
# 23                                                 81
# 24                                                282
# 25                                                 81
# 26                                                 31
# 27                                                 34
# 28                                                629
# 29                                                 12
# 30                                                 57
# 31                                                  6
# 32                                                  5
# 33                                                 54
# 34                                                 27
# 35                                               5423
# 36  Data as of 20 April 2020[27] ^ Counting by cen...
#
#                                      Official website  \
#                                    covid19.bnpb.go.id
# 0                              covid19.acehprov.go.id
# 1                           infocorona.baliprov.go.id
# 2                             covid19.babelprov.go.id
# 3                         infocorona.bantenprov.go.id
# 4                          covid19.bengkuluprov.go.id
# 5                             corona.jatengprov.go.id
# 6                                corona.kalteng.go.id
# 7          dinkes.sultengprov.go.id/category/covid-19
# 8                         infocovid19.jatimprov.go.id
# 9                            covid19.kaltimprov.go.id
# 10  nttprov.go.id/2018/index.php/data-covid-19-pro...
# 11                         dinkes.gorontaloprov.go.id
# 12                               corona.jakarta.go.id
# 13          covid19.jambikota.go.id (Jambi City only)
# 14                geoportal.lampungprov.go.id/corona/
# 15                            corona.malukuprov.go.id
# 16                            humas.kaltaraprov.go.id
# 17                   malutprov.go.id/tag/satgas-covid
# 18                             corona.sulutprov.go.id
# 19                            covid19.sumutprov.go.id
# 20  papua.go.id/view-kategori-berita-14/kategori-b...
# 21                                  corona.riau.go.id
# 22                             corona.kepriprov.go.id
# 23                            corona.kalselprov.go.id
# 24                           covid19.sulselprov.go.id
# 25                            corona.sumselprov.go.id
# 26                            dinkes.sultraprov.go.id
# 27                             corona.jogjaprov.go.id
# 28                            pikobar.jabarprov.go.id
# 29                           covid19.kalbarprov.go.id
# 30                               corona.ntbprov.go.id
# 31                        dinkes.papuabaratprov.go.id
# 32                            dinkes.sulbarprov.go.id
# 33                            corona.sumbarprov.go.id
# 34                                                NaN
# 35                                 covid19.bnpb.go.id
# 36  Data as of 20 April 2020[27] ^ Counting by cen...
#
#                                    Unnamed: 8_level_0  \
#                                    Unnamed: 8_level_1
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36  Data as of 20 April 2020[27] ^ Counting by cen...
#
#                                    Unnamed: 9_level_0
#                                    Unnamed: 9_level_1
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36  Data as of 20 April 2020[27] ^ Counting by cen...

# %% [markdown]
# <hr>
#
# ### 2. Cleaning data

# %%
df = datacorona[3].copy()
df = df.iloc[:36, [0,3,4,5,6]]
df.columns = ['Provinsi', 'Confirmed', 'Recovered', 'Deaths', 'Active cases']

df.iloc[12]['Provinsi'] = 'Jakarta'
# df.iloc[17]['Confirmed'] = 2
df.iloc[2]['Provinsi'] = 'Bangka Belitung'
df.iloc[19]['Provinsi'] = 'North Sumatera'
df.iloc[25]['Provinsi'] = 'South Sumatera'
df.iloc[27]['Provinsi'] = 'Yogyakarta'
df[['Confirmed', 'Recovered', 'Deaths', 'Active cases']] = df[['Confirmed', 'Recovered', 'Deaths', 'Active cases']].astype('int32')

# add tanggal updateUnix & updatestr
df['updateUnix'] = pd.Timestamp.today()
df['updateDate'] = df['updateUnix'].apply(lambda x: str(x).split(' ')[0])
df['updateTime'] = df['updateUnix'].apply(lambda x: str(x).split(' ')[1])

# %%
df
# Out:
#                Provinsi  Confirmed  Recovered  Deaths  Active cases  \
# 0                  Aceh          7          4       1             2
# 1                  Bali        140         42       3            95
# 2       Bangka Belitung          7          1       1             5
# 3                Banten        341         17      35           289
# 4              Bengkulu          4          0       1             3
# 5          Central Java        351         51      44           256
# 6    Central Kalimantan         60          9       3            48
# 7      Central Sulawesi         27          2       3            22
# 8             East Java        588         99      56           433
# 9       East Kalimantan         59         11       1            47
# 10   East Nusa Tenggara          1          0       0             1
# 11            Gorontalo          4          0       0             4
# 12              Jakarta       3097        230     287          2580
# 13                Jambi          8          1       0             7
# 14              Lampung         26         10       5            11
# 15               Maluku         17         10       0             7
# 16     North Kalimantan         74          2       1            71
# 17         North Maluku          4          2       0             2
# 18       North Sulawesi         20          5       2            13
# 19       North Sumatera         83         13       9            61
# 20                Papua        107         28       6            73
# 21                 Riau         34          9       4            21
# 22         Riau Islands         79          6       7            66
# 23     South Kalimantan         96          9       6            81
# 24       South Sulawesi        370         63      25           282
# 25       South Sumatera         89          5       3            81
# 26   Southeast Sulawesi         37          4       2            31
# 27           Yogyakarta         69         28       7            34
# 28            West Java        747         56      62           629
# 29      West Kalimantan         21          6       3            12
# 30   West Nusa Tenggara         72         11       4            57
# 31           West Papua          7          0       1             6
# 32        West Sulawesi          7          1       1             5
# 33         West Sumatra         74         13       7            54
# 34  Under investigation         27          0       0            27
# 35                Total       6760        747     590          5423
#
#                    updateUnix  updateDate       updateTime
# 0  2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 1  2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 2  2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 3  2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 4  2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 5  2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 6  2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 7  2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 8  2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 9  2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 10 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 11 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 12 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 13 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 14 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 15 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 16 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 17 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 18 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 19 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 20 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 21 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 22 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 23 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 24 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 25 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 26 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 27 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 28 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 29 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 30 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 31 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 32 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 33 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 34 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295
# 35 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295

# %% [markdown]
# <hr>
#
# ### 3. Get provinces' position & logo from local file

# %%
prov = pd.read_json('./data/gps_indonesia.json')
prov
# Out:
#               Provinsi  latitude   longitude  \
# 0                 Aceh  4.695135   96.749399
# 1                 Bali -8.409518  115.188916
# 2      Bangka Belitung -2.741051  106.440587
# 3               Banten -6.405817  106.064018
# 4             Bengkulu -3.577847  102.346388
# 5         Central Java -7.150975  110.140259
# 6   Central Kalimantan -1.681488  113.382355
# 7     Central Sulawesi -1.430025  121.445618
# 8            East Java -7.536064  112.238402
# 9      East Kalimantan  1.640630  116.419389
# 10  East Nusa Tenggara -8.657382  121.079370
# 11           Gorontalo  0.699937  122.446724
# 12             Jakarta -6.211544  106.845172
# 13               Jambi -1.485183  102.438058
# 14             Lampung -4.558585  105.406808
# 15              Maluku -3.238462  130.145273
# 16        North Maluku  1.570999  127.808769
# 17    North Kalimantan  1.580213  114.030855
# 18      North Sulawesi  0.624693  123.975002
# 19      North Sumatera  2.115355   99.545097
# 20               Papua -4.269928  138.080353
# 21                Riau  0.293347  101.706829
# 22        Riau Islands  3.945651  108.142867
# 23    South Kalimantan -3.092642  115.283759
# 24      South Sulawesi -3.668799  119.974053
# 25  Southeast Sulawesi -4.144910  122.174605
# 26      South Sumatera -3.319437  103.914399
# 27           West Java -7.090911  107.668887
# 28     West Kalimantan -0.278781  111.475285
# 29  West Nusa Tenggara -8.652933  117.361648
# 30          West Papua -1.336115  133.174716
# 31       West Sulawesi -2.844137  119.232078
# 32        West Sumatra -0.739940  100.800005
# 33          Yogyakarta -7.875385  110.426209
#
#                                                  logo
# 0   https://upload.wikimedia.org/wikipedia/commons...
# 1   https://4.bp.blogspot.com/-ELlrLdH0frM/WSz4Ajq...
# 2   https://upload.wikimedia.org/wikipedia/commons...
# 3   https://upload.wikimedia.org/wikipedia/commons...
# 4   https://upload.wikimedia.org/wikipedia/commons...
# 5   https://upload.wikimedia.org/wikipedia/commons...
# 6   https://upload.wikimedia.org/wikipedia/commons...
# 7   http://1.bp.blogspot.com/-Mb3OPbim3Gw/VrYYo_59...
# 8   https://2.bp.blogspot.com/-S1hrqQnm0nc/XDCpZ6C...
# 9   https://upload.wikimedia.org/wikipedia/commons...
# 10  https://upload.wikimedia.org/wikipedia/commons...
# 11  https://3.bp.blogspot.com/-75ec3fJKhgU/UNl0Tdg...
# 12  https://upload.wikimedia.org/wikipedia/commons...
# 13  https://2.bp.blogspot.com/-y0bGVkW2XfY/Tdui2om...
# 14  https://upload.wikimedia.org/wikipedia/commons...
# 15  https://upload.wikimedia.org/wikipedia/commons...
# 16  https://upload.wikimedia.org/wikipedia/commons...
# 17  https://upload.wikimedia.org/wikipedia/commons...
# 18  https://upload.wikimedia.org/wikipedia/commons...
# 19  https://upload.wikimedia.org/wikipedia/commons...
# 20  https://upload.wikimedia.org/wikipedia/commons...
# 21  https://upload.wikimedia.org/wikipedia/commons...
# 22  https://upload.wikimedia.org/wikipedia/commons...
# 23  https://pngimage.net/wp-content/uploads/2018/0...
# 24  https://upload.wikimedia.org/wikipedia/commons...
# 25  https://upload.wikimedia.org/wikipedia/commons...
# 26  https://upload.wikimedia.org/wikipedia/commons...
# 27  https://3.bp.blogspot.com/-BRV8kAVyi4I/XDX3S86...
# 28  https://upload.wikimedia.org/wikipedia/commons...
# 29  https://upload.wikimedia.org/wikipedia/commons...
# 30  https://upload.wikimedia.org/wikipedia/commons...
# 31  https://upload.wikimedia.org/wikipedia/commons...
# 32  https://upload.wikimedia.org/wikipedia/commons...
# 33  https://upload.wikimedia.org/wikipedia/commons...

# %% [markdown]
# <hr>
#
# ### 4. Merge 2 dataframes

# %%
print(df['Provinsi'].values)
print(prov['Provinsi'].values)
print(len(df['Provinsi'].values))
print(len(prov['Provinsi'].values))
# Out:
# ['Aceh' 'Bali' 'Bangka Belitung' 'Banten' 'Bengkulu' 'Central Java'
#  'Central Kalimantan' 'Central Sulawesi' 'East Java' 'East Kalimantan'
#  'East Nusa Tenggara' 'Gorontalo' 'Jakarta' 'Jambi' 'Lampung' 'Maluku'
#  'North Kalimantan' 'North Maluku' 'North Sulawesi' 'North Sumatera'
#  'Papua' 'Riau' 'Riau Islands' 'South Kalimantan' 'South Sulawesi'
#  'South Sumatera' 'Southeast Sulawesi' 'Yogyakarta' 'West Java'
#  'West Kalimantan' 'West Nusa Tenggara' 'West Papua' 'West Sulawesi'
#  'West Sumatra' 'Under investigation' 'Total']
# ['Aceh' 'Bali' 'Bangka Belitung' 'Banten' 'Bengkulu' 'Central Java'
#  'Central Kalimantan' 'Central Sulawesi' 'East Java' 'East Kalimantan'
#  'East Nusa Tenggara' 'Gorontalo' 'Jakarta' 'Jambi' 'Lampung' 'Maluku'
#  'North Maluku' 'North Kalimantan' 'North Sulawesi' 'North Sumatera'
#  'Papua' 'Riau' 'Riau Islands' 'South Kalimantan' 'South Sulawesi'
#  'Southeast Sulawesi' 'South Sumatera' 'West Java' 'West Kalimantan'
#  'West Nusa Tenggara' 'West Papua' 'West Sulawesi' 'West Sumatra'
#  'Yogyakarta']
# 36
# 34

# %%
dataku = pd.merge(df, prov, on='Provinsi')

# %%
# dataku['Provinsi'].values
dataku
# Out:
#               Provinsi  Confirmed  Recovered  Deaths  Active cases  \
# 0                 Aceh          7          4       1             2
# 1                 Bali        140         42       3            95
# 2      Bangka Belitung          7          1       1             5
# 3               Banten        341         17      35           289
# 4             Bengkulu          4          0       1             3
# 5         Central Java        351         51      44           256
# 6   Central Kalimantan         60          9       3            48
# 7     Central Sulawesi         27          2       3            22
# 8            East Java        588         99      56           433
# 9      East Kalimantan         59         11       1            47
# 10  East Nusa Tenggara          1          0       0             1
# 11           Gorontalo          4          0       0             4
# 12             Jakarta       3097        230     287          2580
# 13               Jambi          8          1       0             7
# 14             Lampung         26         10       5            11
# 15              Maluku         17         10       0             7
# 16    North Kalimantan         74          2       1            71
# 17        North Maluku          4          2       0             2
# 18      North Sulawesi         20          5       2            13
# 19      North Sumatera         83         13       9            61
# 20               Papua        107         28       6            73
# 21                Riau         34          9       4            21
# 22        Riau Islands         79          6       7            66
# 23    South Kalimantan         96          9       6            81
# 24      South Sulawesi        370         63      25           282
# 25      South Sumatera         89          5       3            81
# 26  Southeast Sulawesi         37          4       2            31
# 27          Yogyakarta         69         28       7            34
# 28           West Java        747         56      62           629
# 29     West Kalimantan         21          6       3            12
# 30  West Nusa Tenggara         72         11       4            57
# 31          West Papua          7          0       1             6
# 32       West Sulawesi          7          1       1             5
# 33        West Sumatra         74         13       7            54
#
#                    updateUnix  updateDate       updateTime  latitude  \
# 0  2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295  4.695135
# 1  2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -8.409518
# 2  2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -2.741051
# 3  2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -6.405817
# 4  2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -3.577847
# 5  2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -7.150975
# 6  2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -1.681488
# 7  2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -1.430025
# 8  2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -7.536064
# 9  2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295  1.640630
# 10 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -8.657382
# 11 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295  0.699937
# 12 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -6.211544
# 13 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -1.485183
# 14 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -4.558585
# 15 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -3.238462
# 16 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295  1.580213
# 17 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295  1.570999
# 18 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295  0.624693
# 19 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295  2.115355
# 20 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -4.269928
# 21 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295  0.293347
# 22 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295  3.945651
# 23 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -3.092642
# 24 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -3.668799
# 25 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -3.319437
# 26 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -4.144910
# 27 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -7.875385
# 28 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -7.090911
# 29 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -0.278781
# 30 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -8.652933
# 31 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -1.336115
# 32 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -2.844137
# 33 2020-04-20 19:01:02.424295  2020-04-20  19:01:02.424295 -0.739940
#
#      longitude                                               logo
# 0    96.749399  https://upload.wikimedia.org/wikipedia/commons...
# 1   115.188916  https://4.bp.blogspot.com/-ELlrLdH0frM/WSz4Ajq...
# 2   106.440587  https://upload.wikimedia.org/wikipedia/commons...
# 3   106.064018  https://upload.wikimedia.org/wikipedia/commons...
# 4   102.346388  https://upload.wikimedia.org/wikipedia/commons...
# 5   110.140259  https://upload.wikimedia.org/wikipedia/commons...
# 6   113.382355  https://upload.wikimedia.org/wikipedia/commons...
# 7   121.445618  http://1.bp.blogspot.com/-Mb3OPbim3Gw/VrYYo_59...
# 8   112.238402  https://2.bp.blogspot.com/-S1hrqQnm0nc/XDCpZ6C...
# 9   116.419389  https://upload.wikimedia.org/wikipedia/commons...
# 10  121.079370  https://upload.wikimedia.org/wikipedia/commons...
# 11  122.446724  https://3.bp.blogspot.com/-75ec3fJKhgU/UNl0Tdg...
# 12  106.845172  https://upload.wikimedia.org/wikipedia/commons...
# 13  102.438058  https://2.bp.blogspot.com/-y0bGVkW2XfY/Tdui2om...
# 14  105.406808  https://upload.wikimedia.org/wikipedia/commons...
# 15  130.145273  https://upload.wikimedia.org/wikipedia/commons...
# 16  114.030855  https://upload.wikimedia.org/wikipedia/commons...
# 17  127.808769  https://upload.wikimedia.org/wikipedia/commons...
# 18  123.975002  https://upload.wikimedia.org/wikipedia/commons...
# 19   99.545097  https://upload.wikimedia.org/wikipedia/commons...
# 20  138.080353  https://upload.wikimedia.org/wikipedia/commons...
# 21  101.706829  https://upload.wikimedia.org/wikipedia/commons...
# 22  108.142867  https://upload.wikimedia.org/wikipedia/commons...
# 23  115.283759  https://pngimage.net/wp-content/uploads/2018/0...
# 24  119.974053  https://upload.wikimedia.org/wikipedia/commons...
# 25  103.914399  https://upload.wikimedia.org/wikipedia/commons...
# 26  122.174605  https://upload.wikimedia.org/wikipedia/commons...
# 27  110.426209  https://upload.wikimedia.org/wikipedia/commons...
# 28  107.668887  https://3.bp.blogspot.com/-BRV8kAVyi4I/XDX3S86...
# 29  111.475285  https://upload.wikimedia.org/wikipedia/commons...
# 30  117.361648  https://upload.wikimedia.org/wikipedia/commons...
# 31  133.174716  https://upload.wikimedia.org/wikipedia/commons...
# 32  119.232078  https://upload.wikimedia.org/wikipedia/commons...
# 33  100.800005  https://upload.wikimedia.org/wikipedia/commons...

# %%
waktu = str(df.iloc[33]['updateUnix']).split(' ')
tgl = waktu[0].split('-')
tgl = f'{tgl[2]}-{tgl[1]}-{tgl[0]}'
jam = str(waktu[1]).split('.')[0].split(':')
jam = jam[0] + ':' + jam[1]
tgl, jam
# Out:
# ('20-04-2020', '19:01')

# %% [markdown]
# <hr>
#
# ### 5. Create maps

# %%
# 1st attempt

# set update time
waktu = str(df.iloc[33]['updateUnix']).split(' ')
tgl = waktu[0].split('-')
tgl = f'{tgl[2]}-{tgl[1]}-{tgl[0]}'
jam = str(waktu[1]).split('.')[0].split(':')
jam = jam[0] + ':' + jam[1] + ' WIB'
    
# -3.2998306,117.9473043
peta = fo.Map(
    location = [-0.5273,118.6963],
    tiles = 'OpenStreetMap',
    zoom_start = 5
)

for i in range(34):
    fo.Marker(
        [dataku.iloc[i]['latitude'], dataku.iloc[i]['longitude']],
        popup = '<b>Confirmed:' + str(dataku.iloc[i]['Confirmed']) + '</b><br><b>Recovered:' + str(dataku.iloc[i]['Recovered']) + '</b><br><b>Deaths:' + str(dataku.iloc[i]['Deaths']) + '</b></br><b>Update:' + tgl + ' ' + jam + '</b>',
        tooltip = dataku.iloc[i]['Provinsi'],
        icon = fo.Icon(color='red', prefix='fa', icon='plus-circle')
    ).add_to(peta)

# peta.add_child(fo.LatLngPopup())

peta
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# final result

# set update time
waktu = str(df.iloc[33]['updateUnix']).split(' ')
tgl = waktu[0].split('-')
tgl = f'{tgl[2]}-{tgl[1]}-{tgl[0]}'
jam = str(waktu[1]).split('.')[0].split(':')
jam = jam[0] + ':' + jam[1] + ' WIB'

# -3.2998306,117.9473043
peta = fo.Map(
    location = [-0.5273,118.6963],
    tiles = 'OpenStreetMap',
    zoom_start = 5
)

for i in range(34):
    fo.Marker(
        [dataku.iloc[i]['latitude'], dataku.iloc[i]['longitude']],
        popup = f"<small>{tgl + ' ' + jam}</small><h4><b>{dataku.iloc[i]['Provinsi']}</b></h4><table><tr><th style='color:red'>Confirmed&nbsp;&nbsp;</th><th style='color:green'>Recovered&nbsp;&nbsp;</th><th style='color:black'>Deaths&nbsp;&nbsp;</th></tr><tr><td><center><b style='color:red'>{str(dataku.iloc[i]['Confirmed'])}</b></center></td><td><center><b style='color:green'>{str(dataku.iloc[i]['Recovered'])}</b></center></td><td><center><b>{str(dataku.iloc[i]['Deaths'])}</b></center></td></tr></table>",
        tooltip = dataku.iloc[i]['Provinsi'],
        icon = fo.features.CustomIcon(icon_image=dataku.iloc[i]['logo'] ,icon_size=35)
    ).add_to(peta)
    fo.Circle(
        location = [dataku.iloc[i]['latitude'], dataku.iloc[i]['longitude']],
        radius = int(int(dataku.iloc[i]['Confirmed']) * 100),
        color = 'red',
        fill = True,
        fill_color = 'red',
    ).add_to(peta)

# create legend
logoid = 'https://raw.githubusercontent.com/LintangWisesa/Indonesia-Covid19-Maps/master/img/indonesiaupdate.png'
FloatImage(logoid, bottom=80, left=75).add_to(peta)
logolin = 'https://raw.githubusercontent.com/LintangWisesa/Indonesia-Covid19-Maps/master/img/simplinnovation.png'
FloatImage(logolin, bottom=3, left=77).add_to(peta)

# add text
# fo.Marker(
#     location=[-0.5273,118.6963],
#     icon=fo.DivIcon(html=f"""<div style="font-family: courier new; color: blue">okokokoko</div>""")
# ).add_to(peta)

# fitur klik untuk dpt lat & lng
# peta.add_child(fo.LatLngPopup())

peta.save('0_indo.html')
peta
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <hr>
#
# ### 6. Create JSON for Covid-19 case API

# %%
# list nama provinsi

dataku['Provinsi'].values
# Out:
# array(['Aceh', 'Bali', 'Bangka Belitung', 'Banten', 'Bengkulu',
#        'Central Java', 'Central Kalimantan', 'Central Sulawesi',
#        'East Java', 'East Kalimantan', 'East Nusa Tenggara', 'Gorontalo',
#        'Jakarta', 'Jambi', 'Lampung', 'Maluku', 'North Kalimantan',
#        'North Maluku', 'North Sulawesi', 'North Sumatera', 'Papua',
#        'Riau', 'Riau Islands', 'South Kalimantan', 'South Sulawesi',
#        'South Sumatera', 'Southeast Sulawesi', 'Yogyakarta', 'West Java',
#        'West Kalimantan', 'West Nusa Tenggara', 'West Papua',
#        'West Sulawesi', 'West Sumatra'], dtype=object)

# %%
# data total kasus covid19 di Indonesia (indonesia.json)

indo = df.iloc[35].copy()
indo = indo.drop('Provinsi')
indo['country'] = 'Indonesia'
# indo
indo.to_json('data/indonesia.json', orient = 'index')

# %%
# data total kasus covid19 di Indonesia per provinsi (all.json)

dataku.to_json('data/provinsi/all.json', orient = 'records')

# %%
# data total kasus covid19 per provinsi (namaprov.json)

for i in range(34):
    dataku.iloc[i].to_json(
        'data/provinsi/' + dataku.iloc[i]['Provinsi'] + '.json',
        orient = 'index'
    )

# %% [markdown]
# <hr>
#
# ### 7. Referral Hospitals

# %%
# https://news.detik.com/berita/d-4942353/daftar-rumah-sakit-rujukan-covid-19-seluruh-indonesia/

# daftar seluruh RS rujukan covid19 di Indonesia
rs = pd.read_excel('data/rumah_sakit/hospitals.xlsx')

# %%
rs
# Out:
#                            nama           kotakab        Provinsi  \
# 0        RSUD Dr Zainoel Abidin        Banda Aceh            Aceh
# 1               RSUD Cut Meutia        Aceh Utara            Aceh
# 2             RSUP H Adam Malik             Medan  North Sumatera
# 3    RSUD Kota Padang Sidempuan  Padang Sidempuan  North Sumatera
# 4                RSUD Kabanjahe         Kabanjahe  North Sumatera
# ..                          ...               ...             ...
# 155               RSUD Jayapura          Jayapura           Papua
# 156                RSUD Merauke           Merauke           Papua
# 157                 RSUD Nabire            Nabire           Papua
# 158              RSUD Manokwari         Manokwari      West Papua
# 159       RSUD Kabupaten Sorong            Sorong      West Papua
#
#               telp  latitude   longitude
# 0     (0651) 34562  5.563713   95.337588
# 1     (0645) 46334  5.122169   97.154190
# 2    (061) 8360051  3.518414   98.606449
# 3     (0634) 21780  1.371913   99.269468
# 4     (0628) 20012  3.097958   98.489420
# ..             ...       ...         ...
# 155  (0967) 533616 -2.534945  140.708226
# 156   (0971) 32112 -8.481786  140.386595
# 157   (0984) 21845 -3.342456  135.527399
# 158  (0986) 211440 -0.868614  134.075811
# 159  (0951) 321850 -0.869586  131.244634
#
# [160 rows x 6 columns]

# %%
# daftar seluruh RS rujukan covid19 di Indonesia group by province

rsKab = rs.groupby('Provinsi')

# %%
# print(g.groups) # dict
print(rsKab.groups.keys())
# print(rsKab.groups.values())
# Out:
# dict_keys(['Aceh', 'Bali', 'Bangka Belitung', 'Banten', 'Bengkulu', 'Central Java', 'Central Kalimantan', 'Central Sulawesi', 'East Java', 'East Kalimantan', 'East Nusa Tenggara', 'Gorontalo', 'Jakarta', 'Jambi', 'Lampung', 'Maluku', 'North Kalimantan', 'North Maluku', 'North Sulawesi', 'North Sumatera', 'Papua', 'Riau', 'Riau Islands', 'South Kalimantan', 'South Sulawesi', 'South Sumatera', 'West Java', 'West Kalimantan', 'West Nusa Tenggara', 'West Papua', 'West Sulawesi', 'West Sumatra', 'Yogyakarta'])

# %%
rsKab.get_group('Jakarta')
# Out:
#                                               nama          kotakab Provinsi  \
# 42                            RSPI Sulianti Saroso    Jakarta Utara  Jakarta
# 43                            RSPAD Gatot Soebroto    Jakarta Pusat  Jakarta
# 44                                 RSUD Cengkareng    Jakarta Barat  Jakarta
# 45  RSU Bhayangkara TK I R Said Sukanto (RS Polri)    Jakarta Timur  Jakarta
# 46                               RSUP Persahabatan    Jakarta Timur  Jakarta
# 47                                 RSAL Mintoharjo    Jakarta Pusat  Jakarta
# 48                               RSUD Pasar Minggu  Jakarta Selatan  Jakarta
# 49                                  RSUP Fatmawati  Jakarta Selatan  Jakarta
#
#               telp  latitude   longitude
# 42   (021) 6506559 -6.130091  106.860095
# 43   (021) 3440693 -6.176123  106.835454
# 44  (021) 54372874 -6.142761  106.732716
# 45   (021) 8093288 -6.269548  106.868520
# 46   (021) 4891708 -6.202806  106.882635
# 47   (021) 5703081 -6.210963  106.809238
# 48  (021) 29059999 -6.294192  106.817791
# 49   (021) 7501524 -6.294852  106.793352

# %% [markdown]
# <hr>
#
# ### 8. Referral hospitals Maps

# %%
peta = fo.Map(
    location = [-0.5273,118.6963],
    tiles = 'OpenStreetMap',
    zoom_start = 5
)

for i in range(160):
    fo.Marker(
        [rs.iloc[i]['latitude'], rs.iloc[i]['longitude']],
        popup = fo.Popup(
            f"<h4><b>{rs.iloc[i]['nama']}</b></h4><div>{rs.iloc[i]['kotakab']}, {rs.iloc[i]['Provinsi']}<br>{rs.iloc[i]['telp']}</div>",
            max_width=200, min_width=200
        ),
        tooltip = rs.iloc[i]['Provinsi'],
        icon = fo.Icon(color='red', prefix='fa', icon='plus-circle')
    ).add_to(peta)

logoid = 'https://raw.githubusercontent.com/LintangWisesa/Indonesia-Covid19-Maps/master/img/rs.png'
FloatImage(logoid, bottom=80, left=75).add_to(peta)
logolin = 'https://raw.githubusercontent.com/LintangWisesa/Indonesia-Covid19-Maps/master/img/simplinnovation.png'
FloatImage(logolin, bottom=3, left=77).add_to(peta)

peta.save('0_rs.html')
peta
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <hr>
#
# ### 9. Create JSON for Referral Hospitals API

# %%
# create json: all referral hosiptals

rs.to_json('data/rumah_sakit/all.json', orient = 'records')

# %%
# create json for ref hospital group by province

for i in rsKab.groups.keys():
    rsKab.get_group(i).to_json(
        'data/rumah_sakit/' + i + '.json',
        orient = 'records'
    )
