# %% [markdown]
# # Indonesia Covid-19 Cases by Provinces

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import folium as fo
from folium.plugins import FloatImage

# %% [markdown]
# <hr>
#
# ### 1. Sraping data from [Wikipedia](https://en.wikipedia.org/wiki/2020_coronavirus_pandemic_in_Indonesia)

# %%
# 1a. basic pandas read html table
# data = pd.read_html('https://en.wikipedia.org/wiki/2020_coronavirus_pandemic_in_Indonesia')

# %%
# data[3]

# %%
# 1b. pandas read html from https request
url = 'https://en.wikipedia.org/wiki/2020_coronavirus_pandemic_in_Indonesia'
x = requests.get(url)
datacorona = pd.read_html(x.text)

# %%
datacorona[3]
# Out:
#                                              Province  \
#                                              Province
# 0                                                Aceh
# 1                                                Bali
# 2                                     Bangka Belitung
# 3                                              Banten
# 4                                            Bengkulu
# 5                                        Central Java
# 6                                  Central Kalimantan
# 7                                    Central Sulawesi
# 8                                           East Java
# 9                                     East Kalimantan
# 10                                 East Nusa Tenggara
# 11                                          Gorontalo
# 12                                         Jakarta[b]
# 13                                              Jambi
# 14                                            Lampung
# 15                                             Maluku
# 16                                       North Maluku
# 17                                   North Kalimantan
# 18                                     North Sulawesi
# 19                                     North Sumatera
# 20                                              Papua
# 21                                               Riau
# 22                                       Riau Islands
# 23                                   South Kalimantan
# 24                                     South Sulawesi
# 25                                 Southeast Sulawesi
# 26                                     South Sumatera
# 27                                          West Java
# 28                                    West Kalimantan
# 29                                 West Nusa Tenggara
# 30                                         West Papua
# 31                                      West Sulawesi
# 32                                       West Sumatra
# 33                                         Yogyakarta
# 34                                Under investigation
# 35                                              Total
# 36  Data as of 27 March 2020[114] ^ Counting by ce...
#
#                                             Confirmed  \
#                                                  1414
# 0                                                   5
# 1                                                  19
# 2                                                   1
# 3                                                 128
# 4                                                   0
# 5                                                  81
# 6                                                   7
# 7                                                   3
# 8                                                  91
# 9                                                  17
# 10                                                  0
# 11                                                  0
# 12                                                698
# 13                                                  2
# 14                                                  4
# 15                                                  1
# 16                                                  1
# 17                                                  2
# 18                                                  2
# 19                                                 13
# 20                                                  9
# 21                                                  3
# 22                                                  6
# 23                                                  5
# 24                                                 50
# 25                                                  3
# 26                                                  2
# 27                                                180
# 28                                                  7
# 29                                                  2
# 30                                                  2
# 31                                                  1
# 32                                                  8
# 33                                                 18
# 34                                                 42
# 35                                               1414
# 36  Data as of 27 March 2020[114] ^ Counting by ce...
#
#                                             Recovered  \
#                                                    75
# 0                                                   0
# 1                                                   2
# 2                                                   0
# 3                                                   1
# 4                                                   0
# 5                                                   0
# 6                                                   0
# 7                                                   0
# 8                                                  16
# 9                                                   0
# 10                                                  0
# 11                                                  0
# 12                                                 48
# 13                                                  0
# 14                                                  0
# 15                                                  0
# 16                                                  0
# 17                                                  0
# 18                                                  1
# 19                                                  0
# 20                                                  0
# 21                                                  0
# 22                                                  0
# 23                                                  0
# 24                                                  0
# 25                                                  0
# 26                                                  0
# 27                                                  8
# 28                                                  0
# 29                                                  0
# 30                                                  0
# 31                                                  0
# 32                                                  0
# 33                                                  1
# 34                                                  0
# 35                                                 75
# 36  Data as of 27 March 2020[114] ^ Counting by ce...
#
#                                                Deaths  \
#                                                   122
# 0                                                   0
# 1                                                   2
# 2                                                   0
# 3                                                   4
# 4                                                   0
# 5                                                   7
# 6                                                   0
# 7                                                   0
# 8                                                   8
# 9                                                   0
# 10                                                  0
# 11                                                  0
# 12                                                 74
# 13                                                  0
# 14                                                  0
# 15                                                  0
# 16                                                  0
# 17                                                  0
# 18                                                  0
# 19                                                  1
# 20                                                  0
# 21                                                  0
# 22                                                  1
# 23                                                  0
# 24                                                  1
# 25                                                  0
# 26                                                  2
# 27                                                 20
# 28                                                  0
# 29                                                  0
# 30                                                  0
# 31                                                  0
# 32                                                  0
# 33                                                  2
# 34                                                  0
# 35                                                122
# 36  Data as of 27 March 2020[114] ^ Counting by ce...
#
#                                                Active  \
#                                                  1217
# 0                                                   5
# 1                                                  15
# 2                                                   1
# 3                                                 123
# 4                                                   0
# 5                                                  74
# 6                                                   7
# 7                                                   3
# 8                                                  67
# 9                                                  17
# 10                                                  0
# 11                                                  0
# 12                                                576
# 13                                                  2
# 14                                                  4
# 15                                                  1
# 16                                                  1
# 17                                                  2
# 18                                                  1
# 19                                                 12
# 20                                                  9
# 21                                                  3
# 22                                                  5
# 23                                                  5
# 24                                                 49
# 25                                                  3
# 26                                                  0
# 27                                                152
# 28                                                  7
# 29                                                  2
# 30                                                  2
# 31                                                  1
# 32                                                  8
# 33                                                 15
# 34                                                 42
# 35                                               1217
# 36  Data as of 27 March 2020[114] ^ Counting by ce...
#
#                                      Official website  \
#                                         covid19.go.id
# 0                              covid19.acehprov.go.id
# 1                           infocorona.baliprov.go.id
# 2                                                 NaN
# 3                         infocorona.bantenprov.go.id
# 4                                                 NaN
# 5                             corona.jatengprov.go.id
# 6                                corona.kalteng.go.id
# 7                                                 NaN
# 8                         infocovid19.jatimprov.go.id
# 9                            covid19.kaltimprov.go.id
# 10                                                NaN
# 11                                                NaN
# 12                               corona.jakarta.go.id
# 13                                                NaN
# 14                geoportal.lampungprov.go.id/corona/
# 15                            corona.malukuprov.go.id
# 16                                                NaN
# 17                                                NaN
# 18                             corona.sulutprov.go.id
# 19                                                NaN
# 20                                                NaN
# 21            corona.riau.go.idppc-19.pekanbaru.go.id
# 22                             corona.kepriprov.go.id
# 23                            corona.kalselprov.go.id
# 24                           covid19.sulselprov.go.id
# 25                                                NaN
# 26                            corona.sumselprov.go.id
# 27                            pikobar.jabarprov.go.id
# 28  covid19.kalbarprov.go.idcovid19.pontianakkota....
# 29                               corona.ntbprov.go.id
# 30                                                NaN
# 31                                                NaN
# 32                            corona.sumbarprov.go.id
# 33                             corona.jogjaprov.go.id
# 34                                                NaN
# 35                                      covid19.go.id
# 36  Data as of 27 March 2020[114] ^ Counting by ce...
#
#                                    Unnamed: 6_level_0
#                                    Unnamed: 6_level_1
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36  Data as of 27 March 2020[114] ^ Counting by ce...

# %% [markdown]
# <hr>
#
# ### 2. Cleaning data

# %%
df = datacorona[3].copy()
df = df.iloc[:36, :5]
df.columns = ['Provinsi', 'Confirmed', 'Recovered', 'Deaths', 'Active cases']
df.iloc[12]['Provinsi'] = 'Jakarta'
# df.iloc[17]['Confirmed'] = 2
df[['Confirmed', 'Recovered', 'Deaths', 'Active cases']] = df[['Confirmed', 'Recovered', 'Deaths', 'Active cases']].astype('int32')

# add tanggal update
df['update'] = pd.Timestamp.today()

# %%
df
# Out:
#                Provinsi  Confirmed  Recovered  Deaths  Active cases  \
# 0                  Aceh          5          0       0             5
# 1                  Bali         19          2       2            15
# 2       Bangka Belitung          1          0       0             1
# 3                Banten        128          1       4           123
# 4              Bengkulu          0          0       0             0
# 5          Central Java         81          0       7            74
# 6    Central Kalimantan          7          0       0             7
# 7      Central Sulawesi          3          0       0             3
# 8             East Java         91         16       8            67
# 9       East Kalimantan         17          0       0            17
# 10   East Nusa Tenggara          0          0       0             0
# 11            Gorontalo          0          0       0             0
# 12              Jakarta        698         48      74           576
# 13                Jambi          2          0       0             2
# 14              Lampung          4          0       0             4
# 15               Maluku          1          0       0             1
# 16         North Maluku          1          0       0             1
# 17     North Kalimantan          2          0       0             2
# 18       North Sulawesi          2          1       0             1
# 19       North Sumatera         13          0       1            12
# 20                Papua          9          0       0             9
# 21                 Riau          3          0       0             3
# 22         Riau Islands          6          0       1             5
# 23     South Kalimantan          5          0       0             5
# 24       South Sulawesi         50          0       1            49
# 25   Southeast Sulawesi          3          0       0             3
# 26       South Sumatera          2          0       2             0
# 27            West Java        180          8      20           152
# 28      West Kalimantan          7          0       0             7
# 29   West Nusa Tenggara          2          0       0             2
# 30           West Papua          2          0       0             2
# 31        West Sulawesi          1          0       0             1
# 32         West Sumatra          8          0       0             8
# 33           Yogyakarta         18          1       2            15
# 34  Under investigation         42          0       0            42
# 35                Total       1414         75     122          1217
#
#                        update
# 0  2020-03-31 14:54:03.065610
# 1  2020-03-31 14:54:03.065610
# 2  2020-03-31 14:54:03.065610
# 3  2020-03-31 14:54:03.065610
# 4  2020-03-31 14:54:03.065610
# 5  2020-03-31 14:54:03.065610
# 6  2020-03-31 14:54:03.065610
# 7  2020-03-31 14:54:03.065610
# 8  2020-03-31 14:54:03.065610
# 9  2020-03-31 14:54:03.065610
# 10 2020-03-31 14:54:03.065610
# 11 2020-03-31 14:54:03.065610
# 12 2020-03-31 14:54:03.065610
# 13 2020-03-31 14:54:03.065610
# 14 2020-03-31 14:54:03.065610
# 15 2020-03-31 14:54:03.065610
# 16 2020-03-31 14:54:03.065610
# 17 2020-03-31 14:54:03.065610
# 18 2020-03-31 14:54:03.065610
# 19 2020-03-31 14:54:03.065610
# 20 2020-03-31 14:54:03.065610
# 21 2020-03-31 14:54:03.065610
# 22 2020-03-31 14:54:03.065610
# 23 2020-03-31 14:54:03.065610
# 24 2020-03-31 14:54:03.065610
# 25 2020-03-31 14:54:03.065610
# 26 2020-03-31 14:54:03.065610
# 27 2020-03-31 14:54:03.065610
# 28 2020-03-31 14:54:03.065610
# 29 2020-03-31 14:54:03.065610
# 30 2020-03-31 14:54:03.065610
# 31 2020-03-31 14:54:03.065610
# 32 2020-03-31 14:54:03.065610
# 33 2020-03-31 14:54:03.065610
# 34 2020-03-31 14:54:03.065610
# 35 2020-03-31 14:54:03.065610

# %% [markdown]
# <hr>
#
# ### 3. Get provinces' position & logo from local file

# %%
prov = pd.read_json('./data/gps_indonesia.json')
prov
# Out:
#               Provinsi  latitude   longitude  \
# 0                 Aceh  4.695135   96.749399
# 1                 Bali -8.409518  115.188916
# 2      Bangka Belitung -2.741051  106.440587
# 3               Banten -6.405817  106.064018
# 4             Bengkulu -3.577847  102.346388
# 5         Central Java -7.150975  110.140259
# 6   Central Kalimantan -1.681488  113.382355
# 7     Central Sulawesi -1.430025  121.445618
# 8            East Java -7.536064  112.238402
# 9      East Kalimantan  1.640630  116.419389
# 10  East Nusa Tenggara -8.657382  121.079370
# 11           Gorontalo  0.699937  122.446724
# 12             Jakarta -6.211544  106.845172
# 13               Jambi -1.485183  102.438058
# 14             Lampung -4.558585  105.406808
# 15              Maluku -3.238462  130.145273
# 16        North Maluku  1.570999  127.808769
# 17    North Kalimantan  1.580213  114.030855
# 18      North Sulawesi  0.624693  123.975002
# 19      North Sumatera  2.115355   99.545097
# 20               Papua -4.269928  138.080353
# 21                Riau  0.293347  101.706829
# 22        Riau Islands  3.945651  108.142867
# 23    South Kalimantan -3.092642  115.283759
# 24      South Sulawesi -3.668799  119.974053
# 25  Southeast Sulawesi -4.144910  122.174605
# 26      South Sumatera -3.319437  103.914399
# 27           West Java -7.090911  107.668887
# 28     West Kalimantan -0.278781  111.475285
# 29  West Nusa Tenggara -8.652933  117.361648
# 30          West Papua -1.336115  133.174716
# 31       West Sulawesi -2.844137  119.232078
# 32        West Sumatra -0.739940  100.800005
# 33          Yogyakarta -7.875385  110.426209
#
#                                                  logo
# 0   https://upload.wikimedia.org/wikipedia/commons...
# 1   https://4.bp.blogspot.com/-ELlrLdH0frM/WSz4Ajq...
# 2   https://upload.wikimedia.org/wikipedia/commons...
# 3   https://upload.wikimedia.org/wikipedia/commons...
# 4   https://upload.wikimedia.org/wikipedia/commons...
# 5   https://upload.wikimedia.org/wikipedia/commons...
# 6   https://upload.wikimedia.org/wikipedia/commons...
# 7   http://1.bp.blogspot.com/-Mb3OPbim3Gw/VrYYo_59...
# 8   https://2.bp.blogspot.com/-S1hrqQnm0nc/XDCpZ6C...
# 9   https://upload.wikimedia.org/wikipedia/commons...
# 10  https://upload.wikimedia.org/wikipedia/commons...
# 11  https://3.bp.blogspot.com/-75ec3fJKhgU/UNl0Tdg...
# 12  https://upload.wikimedia.org/wikipedia/commons...
# 13  https://2.bp.blogspot.com/-y0bGVkW2XfY/Tdui2om...
# 14  https://upload.wikimedia.org/wikipedia/commons...
# 15  https://upload.wikimedia.org/wikipedia/commons...
# 16  https://upload.wikimedia.org/wikipedia/commons...
# 17  https://upload.wikimedia.org/wikipedia/commons...
# 18  https://upload.wikimedia.org/wikipedia/commons...
# 19  https://upload.wikimedia.org/wikipedia/commons...
# 20  https://upload.wikimedia.org/wikipedia/commons...
# 21  https://upload.wikimedia.org/wikipedia/commons...
# 22  https://upload.wikimedia.org/wikipedia/commons...
# 23  https://pngimage.net/wp-content/uploads/2018/0...
# 24  https://upload.wikimedia.org/wikipedia/commons...
# 25  https://upload.wikimedia.org/wikipedia/commons...
# 26  https://upload.wikimedia.org/wikipedia/commons...
# 27  https://3.bp.blogspot.com/-BRV8kAVyi4I/XDX3S86...
# 28  https://upload.wikimedia.org/wikipedia/commons...
# 29  https://upload.wikimedia.org/wikipedia/commons...
# 30  https://upload.wikimedia.org/wikipedia/commons...
# 31  https://upload.wikimedia.org/wikipedia/commons...
# 32  https://upload.wikimedia.org/wikipedia/commons...
# 33  https://upload.wikimedia.org/wikipedia/commons...

# %% [markdown]
# <hr>
#
# ### 4. Merge 2 dataframes

# %%
dataku = pd.merge(df, prov, on='Provinsi')

# %%
dataku
# Out:
#               Provinsi  Confirmed  Recovered  Deaths  Active cases  \
# 0                 Aceh          5          0       0             5
# 1                 Bali         19          2       2            15
# 2      Bangka Belitung          1          0       0             1
# 3               Banten        128          1       4           123
# 4             Bengkulu          0          0       0             0
# 5         Central Java         81          0       7            74
# 6   Central Kalimantan          7          0       0             7
# 7     Central Sulawesi          3          0       0             3
# 8            East Java         91         16       8            67
# 9      East Kalimantan         17          0       0            17
# 10  East Nusa Tenggara          0          0       0             0
# 11           Gorontalo          0          0       0             0
# 12             Jakarta        698         48      74           576
# 13               Jambi          2          0       0             2
# 14             Lampung          4          0       0             4
# 15              Maluku          1          0       0             1
# 16        North Maluku          1          0       0             1
# 17    North Kalimantan          2          0       0             2
# 18      North Sulawesi          2          1       0             1
# 19      North Sumatera         13          0       1            12
# 20               Papua          9          0       0             9
# 21                Riau          3          0       0             3
# 22        Riau Islands          6          0       1             5
# 23    South Kalimantan          5          0       0             5
# 24      South Sulawesi         50          0       1            49
# 25  Southeast Sulawesi          3          0       0             3
# 26      South Sumatera          2          0       2             0
# 27           West Java        180          8      20           152
# 28     West Kalimantan          7          0       0             7
# 29  West Nusa Tenggara          2          0       0             2
# 30          West Papua          2          0       0             2
# 31       West Sulawesi          1          0       0             1
# 32        West Sumatra          8          0       0             8
# 33          Yogyakarta         18          1       2            15
#
#                        update  latitude   longitude  \
# 0  2020-03-31 14:54:03.065610  4.695135   96.749399
# 1  2020-03-31 14:54:03.065610 -8.409518  115.188916
# 2  2020-03-31 14:54:03.065610 -2.741051  106.440587
# 3  2020-03-31 14:54:03.065610 -6.405817  106.064018
# 4  2020-03-31 14:54:03.065610 -3.577847  102.346388
# 5  2020-03-31 14:54:03.065610 -7.150975  110.140259
# 6  2020-03-31 14:54:03.065610 -1.681488  113.382355
# 7  2020-03-31 14:54:03.065610 -1.430025  121.445618
# 8  2020-03-31 14:54:03.065610 -7.536064  112.238402
# 9  2020-03-31 14:54:03.065610  1.640630  116.419389
# 10 2020-03-31 14:54:03.065610 -8.657382  121.079370
# 11 2020-03-31 14:54:03.065610  0.699937  122.446724
# 12 2020-03-31 14:54:03.065610 -6.211544  106.845172
# 13 2020-03-31 14:54:03.065610 -1.485183  102.438058
# 14 2020-03-31 14:54:03.065610 -4.558585  105.406808
# 15 2020-03-31 14:54:03.065610 -3.238462  130.145273
# 16 2020-03-31 14:54:03.065610  1.570999  127.808769
# 17 2020-03-31 14:54:03.065610  1.580213  114.030855
# 18 2020-03-31 14:54:03.065610  0.624693  123.975002
# 19 2020-03-31 14:54:03.065610  2.115355   99.545097
# 20 2020-03-31 14:54:03.065610 -4.269928  138.080353
# 21 2020-03-31 14:54:03.065610  0.293347  101.706829
# 22 2020-03-31 14:54:03.065610  3.945651  108.142867
# 23 2020-03-31 14:54:03.065610 -3.092642  115.283759
# 24 2020-03-31 14:54:03.065610 -3.668799  119.974053
# 25 2020-03-31 14:54:03.065610 -4.144910  122.174605
# 26 2020-03-31 14:54:03.065610 -3.319437  103.914399
# 27 2020-03-31 14:54:03.065610 -7.090911  107.668887
# 28 2020-03-31 14:54:03.065610 -0.278781  111.475285
# 29 2020-03-31 14:54:03.065610 -8.652933  117.361648
# 30 2020-03-31 14:54:03.065610 -1.336115  133.174716
# 31 2020-03-31 14:54:03.065610 -2.844137  119.232078
# 32 2020-03-31 14:54:03.065610 -0.739940  100.800005
# 33 2020-03-31 14:54:03.065610 -7.875385  110.426209
#
#                                                  logo
# 0   https://upload.wikimedia.org/wikipedia/commons...
# 1   https://4.bp.blogspot.com/-ELlrLdH0frM/WSz4Ajq...
# 2   https://upload.wikimedia.org/wikipedia/commons...
# 3   https://upload.wikimedia.org/wikipedia/commons...
# 4   https://upload.wikimedia.org/wikipedia/commons...
# 5   https://upload.wikimedia.org/wikipedia/commons...
# 6   https://upload.wikimedia.org/wikipedia/commons...
# 7   http://1.bp.blogspot.com/-Mb3OPbim3Gw/VrYYo_59...
# 8   https://2.bp.blogspot.com/-S1hrqQnm0nc/XDCpZ6C...
# 9   https://upload.wikimedia.org/wikipedia/commons...
# 10  https://upload.wikimedia.org/wikipedia/commons...
# 11  https://3.bp.blogspot.com/-75ec3fJKhgU/UNl0Tdg...
# 12  https://upload.wikimedia.org/wikipedia/commons...
# 13  https://2.bp.blogspot.com/-y0bGVkW2XfY/Tdui2om...
# 14  https://upload.wikimedia.org/wikipedia/commons...
# 15  https://upload.wikimedia.org/wikipedia/commons...
# 16  https://upload.wikimedia.org/wikipedia/commons...
# 17  https://upload.wikimedia.org/wikipedia/commons...
# 18  https://upload.wikimedia.org/wikipedia/commons...
# 19  https://upload.wikimedia.org/wikipedia/commons...
# 20  https://upload.wikimedia.org/wikipedia/commons...
# 21  https://upload.wikimedia.org/wikipedia/commons...
# 22  https://upload.wikimedia.org/wikipedia/commons...
# 23  https://pngimage.net/wp-content/uploads/2018/0...
# 24  https://upload.wikimedia.org/wikipedia/commons...
# 25  https://upload.wikimedia.org/wikipedia/commons...
# 26  https://upload.wikimedia.org/wikipedia/commons...
# 27  https://3.bp.blogspot.com/-BRV8kAVyi4I/XDX3S86...
# 28  https://upload.wikimedia.org/wikipedia/commons...
# 29  https://upload.wikimedia.org/wikipedia/commons...
# 30  https://upload.wikimedia.org/wikipedia/commons...
# 31  https://upload.wikimedia.org/wikipedia/commons...
# 32  https://upload.wikimedia.org/wikipedia/commons...
# 33  https://upload.wikimedia.org/wikipedia/commons...

# %%
waktu = str(df.iloc[33]['update']).split(' ')
tgl = waktu[0]
jam = str(waktu[1]).split('.')[0].split(':')
jam = jam[0] + ':' + jam[1]
tgl, jam
# Out:
# ('2020-03-31', '14:54')

# %% [markdown]
# <hr>
#
# ### 5. Create maps

# %%
# 1st attempt

# set update time
waktu = str(df.iloc[0]['update']).split(' ')
tgl = waktu[0]
jam = str(waktu[1]).split('.')[0].split(':')
jam = jam[0] + ':' + jam[1]
    
# -3.2998306,117.9473043
peta = fo.Map(
    location = [-0.5273,118.6963],
    tiles = 'OpenStreetMap',
    zoom_start = 5
)

for i in range(34):
    fo.Marker(
        [dataku.iloc[i]['latitude'], dataku.iloc[i]['longitude']],
        popup = '<b>Confirmed:' + str(dataku.iloc[i]['Confirmed']) + '</b><br><b>Recovered:' + str(dataku.iloc[i]['Recovered']) + '</b><br><b>Deaths:' + str(dataku.iloc[i]['Deaths']) + '</b></br><b>Update:' + tgl + ' ' + jam + '</b>',
        tooltip = dataku.iloc[i]['Provinsi'],
        icon = fo.Icon(color='red', prefix='fa', icon='plus-circle')
    ).add_to(peta)

# peta.add_child(fo.LatLngPopup())

peta
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# final result

# set update time
waktu = str(df.iloc[0]['update']).split(' ')
tgl = waktu[0]
jam = str(waktu[1]).split('.')[0].split(':')
jam = jam[0] + ':' + jam[1] + ' WIB'

# -3.2998306,117.9473043
peta = fo.Map(
    location = [-0.5273,118.6963],
    tiles = 'OpenStreetMap',
    zoom_start = 5
)

for i in range(34):
    fo.Marker(
        [dataku.iloc[i]['latitude'], dataku.iloc[i]['longitude']],
        popup = f"<small>{tgl + ' ' + jam}</small><h4><b>{dataku.iloc[i]['Provinsi']}</b></h4><table><tr><th style='color:red'>Confirmed&nbsp;&nbsp;</th><th style='color:green'>Recovered&nbsp;&nbsp;</th><th style='color:black'>Deaths&nbsp;&nbsp;</th></tr><tr><td><center><b style='color:red'>{str(dataku.iloc[i]['Confirmed'])}</b></center></td><td><center><b style='color:green'>{str(dataku.iloc[i]['Recovered'])}</b></center></td><td><center><b>{str(dataku.iloc[i]['Deaths'])}</b></center></td></tr></table>",
        tooltip = dataku.iloc[i]['Provinsi'],
        icon = fo.features.CustomIcon(icon_image=dataku.iloc[i]['logo'] ,icon_size=35)
    ).add_to(peta)
    fo.Circle(
        location = [dataku.iloc[i]['latitude'], dataku.iloc[i]['longitude']],
        radius = int(int(dataku.iloc[i]['Confirmed']) * 100),
        color = 'red',
        fill = True,
        fill_color = 'red',
    ).add_to(peta)

# create legend
logoid = 'https://raw.githubusercontent.com/LintangWisesa/Indonesia-Covid19-Maps/master/img/indonesiaupdate.png'
FloatImage(logoid, bottom=80, left=75).add_to(peta)
logolin = 'https://raw.githubusercontent.com/LintangWisesa/Indonesia-Covid19-Maps/master/img/simplinnovation.png'
FloatImage(logolin, bottom=3, left=77).add_to(peta)

# add text
# fo.Marker(
#     location=[-0.5273,118.6963],
#     icon=fo.DivIcon(html=f"""<div style="font-family: courier new; color: blue">okokokoko</div>""")
# ).add_to(peta)

# fitur klik untuk dpt lat & lng
# peta.add_child(fo.LatLngPopup())

peta.save('0_indo.html')
peta
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <hr>
#
# ### 6. Create JSON

# %%
# data total kasus covid19 di Indonesia

indo = df.iloc[35].copy()
indo.to_json('data/indonesia.json', orient = 'index')

# %%
# data total kasus covid19 per provinsi

for i in range(34):
    dataku.iloc[i].to_json(
        'data/provinsi/' + dataku.iloc[i]['Provinsi'] + '.json',
        orient = 'index'
    )
